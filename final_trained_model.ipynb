# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model

# %%
# Pip install method (recommended)


# %pip install ultralytics==8.0.2

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.2  Python-3.10.11 torch-2.0.1+cpu CPU
# Setup complete  (16 CPUs, 13.8 GB RAM, 144.4/951.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
os.makedirs("datasets", exist_ok=True)

# %pip install roboflow
'''

from roboflow import Roboflow
rf = Roboflow(api_key="tUZCeeGNLljUnpXXsngy")
project = rf.workspace("swastik-abhijit-patra-zlamm").project("real-time-parking-lot-vehicle-detection")
dataset = project.version(1).download("yolov8")
'''
# Out:
# '\n\nfrom roboflow import Roboflow\nrf = Roboflow(api_key="tUZCeeGNLljUnpXXsngy")\nproject = rf.workspace("swastik-abhijit-patra-zlamm").project("real-time-parking-lot-vehicle-detection")\ndataset = project.version(1).download("yolov8")\n'

# %%
# %cd {HOME}
from ultralytics import YOLO
'''
# Load the base pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

import sys
# !{sys.executable} -m pip install --force-reinstall --no-cache-dir numpy

import numpy as np
print("✅ NumPy version:", np.__version__)



# Start training
model.train(
    data="Real-time-parking-lot-vehicle-detection-1/data.yaml",  # path to your dataset config
    epochs=10,
    imgsz=640,
    name="custom_yolov8n"
)


'''
#!yolo task=detect mode=train model=yolov8m.pt data=r'C:\Users\hp\Desktop\car_parking_slot_occupancy_detection_using_yolov8\Real-time-parking-lot-vehicle-detection-1\data.yaml' epochs=30 imgsz=640 plots=True
# Out:
# c:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model
# '\n# Load the base pretrained YOLOv8n model\nmodel = YOLO("yolov8n.pt")\n\nimport sys\n!{sys.executable} -m pip install --force-reinstall --no-cache-dir numpy\n\nimport numpy as np\nprint("✅ NumPy version:", np.__version__)\n\n\n\n# Start training\nmodel.train(\n    data="Real-time-parking-lot-vehicle-detection-1/data.yaml",  # path to your dataset config\n    epochs=10,\n    imgsz=640,\n    name="custom_yolov8n"\n)\n\n\n'

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd {HOME}
#Image(filename=f'/runs/detect/train/confusion_matrix.jpg', width=600)
#"C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\conf matrix.jpg"
from IPython.display import Image

Image(filename=r"C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\runs\detect\train5\confusion_matrix.png", width=600)
# Out:
# c:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model="runs/detect/train5/weights/best.pt" data="Real-time-parking-lot-vehicle-detection-1\data.yaml"
# Out:
# c:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model
# Ultralytics YOLOv8.0.2  Python-3.10.11 torch-2.0.1+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# val: Scanning C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\Real-time-parking-lot-vehicle-detection-1\valid\labels...:   0%|          | 0/215 [00:00<?, ?it/s]
# val: Scanning C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\Real-time-parking-lot-vehicle-detection-1\valid\labels... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/215 [00:06<23:22,  6.55s/it]
# val: Scanning C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\Real-time-parking-lot-vehicle-detection-1\valid\labels... 69 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 69/215 [00:06<00:09, 14.66it/s]
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model="runs/detect/train5/weights/best.pt" conf=0.40 source=test2.mp4 save=True      #test
# Out:
# c:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model
# Ultralytics YOLOv8.0.2  Python-3.10.11 torch-2.0.1+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 55 cars, 1 free, 86.5ms
# video 1/1 (2/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 55 cars, 1 free, 64.7ms
# video 1/1 (3/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 54 cars, 1 free, 57.4ms
# video 1/1 (4/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 55 cars, 1 free, 58.1ms
# video 1/1 (5/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 54 cars, 1 free, 61.5ms
# video 1/1 (6/432) C:\Users\Han\Car-Parking-Slot-Ocuupancy-detection-model\test2.mp4: 384x640 55 cars, 1 free, 68.4ms
# ...
